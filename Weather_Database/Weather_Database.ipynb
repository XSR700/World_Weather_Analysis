# %%
# Import the random module.
import random

# %%
# Import the NumPy module.
import numpy as np

# %%
# Import timeit.
import timeit

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c22189d3f4e0d6855547470e5ba9481"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c22189d3f4e0d6855547470e5ba9481

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c22189d3f4e0d6855547470e5ba9481&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 55.62,
#   'feels_like': 54.91,
#   'temp_min': 52.32,
#   'temp_max': 58.37,
#   'pressure': 1004,
#   'humidity': 86},
#  'visibility': 10000,
#  'wind': {'speed': 1.99, 'deg': 302, 'gust': 11.01},
#  'clouds': {'all': 75},
#  'dt': 1635729822,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1635678990,
#   'sunset': 1635716342},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['weather'][0]['description']
# Out:
# 'broken clouds'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
# datetime.utcfromtimestamp(date)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 1 | katherine
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | richards bay
# Processing Record 10 of Set 1 | kathu
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | traverse city
# Processing Record 13 of Set 1 | port hedland
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | maragogi
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | requena
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | poum
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | cockburn town
# Processing Record 23 of Set 1 | longyearbyen
# Processing Record 24 of Set 1 | saskylakh
# Processing Record 25 of Set 1 | plettenberg bay
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | meulaboh
# Processing Record 29 of Set 1 | shush
# Processing Record 30 of Set 1 | sola
# Processing Record 31 of Set 1 | souillac
# Processing Record 32 of Set 1 | ormara
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | san andres
# Processing Record 37 of Set 1 | narsaq
# Processing Record 38 of Set 1 | lasa
# Processing Record 39 of Set 1 | acapulco
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | isangel
# Processing Record 42 of Set 1 | tuatapere
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 1 | wanlaweyn
# Processing Record 46 of Set 1 | cabatuan
# Processing Record 47 of Set 1 | nanortalik
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | kavieng
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | pisco
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | doctor juan manuel frutos
# Processing Record 7 of Set 2 | sarankhola
# Processing Record 8 of Set 2 | saint george
# Processing Record 9 of Set 2 | aniva
# Processing Record 10 of Set 2 | anta
# Processing Record 11 of Set 2 | fairlie
# Processing Record 12 of Set 2 | castro
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | palimbang
# Processing Record 16 of Set 2 | cabra
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | huarmey
# Processing Record 22 of Set 2 | sal rei
# Processing Record 23 of Set 2 | selm
# Processing Record 24 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 2 | havelock
# Processing Record 26 of Set 2 | bonavista
# Processing Record 27 of Set 2 | mount darwin
# Processing Record 28 of Set 2 | luwuk
# Processing Record 29 of Set 2 | izumo
# Processing Record 30 of Set 2 | atar
# Processing Record 31 of Set 2 | cabo san lucas
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | shingu
# Processing Record 34 of Set 2 | rapid valley
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | bathsheba
# Processing Record 37 of Set 2 | kargasok
# Processing Record 38 of Set 2 | torbay
# Processing Record 39 of Set 2 | tiksi
# Processing Record 40 of Set 2 | shchuchye
# City not found. Skipping...
# Processing Record 41 of Set 2 | ancud
# Processing Record 42 of Set 2 | dongsheng
# Processing Record 43 of Set 2 | flong
# Processing Record 44 of Set 2 | te anau
# Processing Record 45 of Set 2 | zhangye
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | morgan city
# Processing Record 48 of Set 2 | coihaique
# Processing Record 49 of Set 2 | san patricio
# Processing Record 50 of Set 2 | saldanha
# Processing Record 1 of Set 3 | ibra
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | broome
# Processing Record 4 of Set 3 | esperance
# Processing Record 5 of Set 3 | padang
# Processing Record 6 of Set 3 | port elizabeth
# Processing Record 7 of Set 3 | hithadhoo
# Processing Record 8 of Set 3 | fairbanks
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 3 | crixas
# Processing Record 11 of Set 3 | ammon
# Processing Record 12 of Set 3 | hailin
# Processing Record 13 of Set 3 | nata
# Processing Record 14 of Set 3 | marrakesh
# Processing Record 15 of Set 3 | mount isa
# Processing Record 16 of Set 3 | cedar city
# Processing Record 17 of Set 3 | ekhabi
# Processing Record 18 of Set 3 | malanje
# Processing Record 19 of Set 3 | awjilah
# Processing Record 20 of Set 3 | brae
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | finnsnes
# Processing Record 23 of Set 3 | shemysheyka
# Processing Record 24 of Set 3 | tabuk
# Processing Record 25 of Set 3 | hobart
# Processing Record 26 of Set 3 | atuona
# Processing Record 27 of Set 3 | vadso
# Processing Record 28 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 3 | egvekinot
# Processing Record 30 of Set 3 | tanout
# Processing Record 31 of Set 3 | mount gambier
# Processing Record 32 of Set 3 | kungsbacka
# Processing Record 33 of Set 3 | cayenne
# Processing Record 34 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | mapiripan
# Processing Record 37 of Set 3 | yermakovskoye
# Processing Record 38 of Set 3 | utiel
# Processing Record 39 of Set 3 | nola
# Processing Record 40 of Set 3 | ryabovo
# Processing Record 41 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 3 | san policarpo
# Processing Record 43 of Set 3 | olafsvik
# Processing Record 44 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 3 | winneba
# Processing Record 46 of Set 3 | vangaindrano
# Processing Record 47 of Set 3 | gushikawa
# Processing Record 48 of Set 3 | weligama
# Processing Record 49 of Set 3 | naze
# Processing Record 50 of Set 3 | mar del plata
# Processing Record 1 of Set 4 | kourou
# Processing Record 2 of Set 4 | waw
# Processing Record 3 of Set 4 | benghazi
# Processing Record 4 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 4 | airai
# Processing Record 6 of Set 4 | pandan
# Processing Record 7 of Set 4 | hasaki
# Processing Record 8 of Set 4 | sembe
# Processing Record 9 of Set 4 | tuktoyaktuk
# Processing Record 10 of Set 4 | markova
# Processing Record 11 of Set 4 | santa maria do suacui
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 14 of Set 4 | cayeli
# Processing Record 15 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 16 of Set 4 | abalak
# Processing Record 17 of Set 4 | port augusta
# Processing Record 18 of Set 4 | beloha
# Processing Record 19 of Set 4 | kulhudhuffushi
# Processing Record 20 of Set 4 | santiago
# Processing Record 21 of Set 4 | dhanwar
# Processing Record 22 of Set 4 | santa maria
# Processing Record 23 of Set 4 | saint anthony
# Processing Record 24 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 25 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 4 | college
# Processing Record 27 of Set 4 | saint-philippe
# Processing Record 28 of Set 4 | sistranda
# Processing Record 29 of Set 4 | la brea
# Processing Record 30 of Set 4 | svetlyy
# Processing Record 31 of Set 4 | klaksvik
# Processing Record 32 of Set 4 | kapaa
# Processing Record 33 of Set 4 | comodoro rivadavia
# Processing Record 34 of Set 4 | katsuura
# Processing Record 35 of Set 4 | shu
# Processing Record 36 of Set 4 | poronaysk
# Processing Record 37 of Set 4 | santa vitoria do palmar
# Processing Record 38 of Set 4 | lavrentiya
# Processing Record 39 of Set 4 | nakusp
# Processing Record 40 of Set 4 | ankara
# Processing Record 41 of Set 4 | kodiak
# Processing Record 42 of Set 4 | havre-saint-pierre
# Processing Record 43 of Set 4 | cidreira
# Processing Record 44 of Set 4 | juchitepec
# Processing Record 45 of Set 4 | vao
# Processing Record 46 of Set 4 | nioro
# Processing Record 47 of Set 4 | milton
# Processing Record 48 of Set 4 | caravelas
# Processing Record 49 of Set 4 | novo aripuana
# Processing Record 50 of Set 4 | bethel
# Processing Record 1 of Set 5 | high level
# Processing Record 2 of Set 5 | akureyri
# Processing Record 3 of Set 5 | severo-kurilsk
# Processing Record 4 of Set 5 | ribeira grande
# Processing Record 5 of Set 5 | lagunas
# Processing Record 6 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 5 | voyvozh
# Processing Record 8 of Set 5 | chicama
# Processing Record 9 of Set 5 | along
# Processing Record 10 of Set 5 | upernavik
# Processing Record 11 of Set 5 | fort nelson
# Processing Record 12 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 5 | taybad
# Processing Record 14 of Set 5 | antalaha
# Processing Record 15 of Set 5 | valparaiso
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | swellendam
# Processing Record 18 of Set 5 | guerrero negro
# Processing Record 19 of Set 5 | lubango
# Processing Record 20 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 5 | camaqua
# Processing Record 23 of Set 5 | coquimbo
# Processing Record 24 of Set 5 | clyde river
# Processing Record 25 of Set 5 | necochea
# Processing Record 26 of Set 5 | kruisfontein
# Processing Record 27 of Set 5 | cherskiy
# Processing Record 28 of Set 5 | carutapera
# Processing Record 29 of Set 5 | provideniya
# Processing Record 30 of Set 5 | winslow
# Processing Record 31 of Set 5 | iskateley
# Processing Record 32 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 5 | san miguel
# Processing Record 35 of Set 5 | gamba
# Processing Record 36 of Set 5 | hobyo
# Processing Record 37 of Set 5 | tomatlan
# Processing Record 38 of Set 5 | tete
# Processing Record 39 of Set 5 | serowe
# Processing Record 40 of Set 5 | bulgan
# Processing Record 41 of Set 5 | ipswich
# Processing Record 42 of Set 5 | norman wells
# Processing Record 43 of Set 5 | samarai
# Processing Record 44 of Set 5 | yulara
# Processing Record 45 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 5 | the valley
# Processing Record 47 of Set 5 | linhares
# Processing Record 48 of Set 5 | victoria
# Processing Record 49 of Set 5 | curanilahue
# Processing Record 50 of Set 5 | izhma
# Processing Record 1 of Set 6 | dingle
# Processing Record 2 of Set 6 | talnakh
# Processing Record 3 of Set 6 | lafiagi
# Processing Record 4 of Set 6 | monte carmelo
# Processing Record 5 of Set 6 | bukene
# Processing Record 6 of Set 6 | vila franca do campo
# Processing Record 7 of Set 6 | sebezh
# Processing Record 8 of Set 6 | bengkulu
# Processing Record 9 of Set 6 | sabha
# Processing Record 10 of Set 6 | mossendjo
# Processing Record 11 of Set 6 | sarai
# Processing Record 12 of Set 6 | sioux lookout
# Processing Record 13 of Set 6 | almaznyy
# Processing Record 14 of Set 6 | oum hadjer
# Processing Record 15 of Set 6 | dikson
# Processing Record 16 of Set 6 | envira
# Processing Record 17 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 6 | pacific grove
# Processing Record 19 of Set 6 | nicoya
# Processing Record 20 of Set 6 | gap
# Processing Record 21 of Set 6 | tekeli
# Processing Record 22 of Set 6 | uyuni
# Processing Record 23 of Set 6 | saint-joseph
# Processing Record 24 of Set 6 | geraldton
# Processing Record 25 of Set 6 | aksu
# Processing Record 26 of Set 6 | mafinga
# Processing Record 27 of Set 6 | liverpool
# Processing Record 28 of Set 6 | maicao
# Processing Record 29 of Set 6 | ixtapa
# Processing Record 30 of Set 6 | paita
# Processing Record 31 of Set 6 | flin flon
# Processing Record 32 of Set 6 | half moon bay
# Processing Record 33 of Set 6 | banda aceh
# Processing Record 34 of Set 6 | daloa
# Processing Record 35 of Set 6 | galveston
# Processing Record 36 of Set 6 | mecca
# Processing Record 37 of Set 6 | westerland
# Processing Record 38 of Set 6 | onguday
# Processing Record 39 of Set 6 | zverinogolovskoye
# Processing Record 40 of Set 6 | kikwit
# Processing Record 41 of Set 6 | mariental
# Processing Record 42 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 6 | sao joao da barra
# Processing Record 44 of Set 6 | da lat
# Processing Record 45 of Set 6 | estrela
# Processing Record 46 of Set 6 | victor harbor
# Processing Record 47 of Set 6 | rocha
# Processing Record 48 of Set 6 | flinders
# Processing Record 49 of Set 6 | okha
# Processing Record 50 of Set 6 | kavaratti
# Processing Record 1 of Set 7 | tautira
# Processing Record 2 of Set 7 | cervo
# Processing Record 3 of Set 7 | vila do maio
# Processing Record 4 of Set 7 | santarem
# Processing Record 5 of Set 7 | palmer
# Processing Record 6 of Set 7 | constitucion
# Processing Record 7 of Set 7 | lagoa
# Processing Record 8 of Set 7 | sorgun
# Processing Record 9 of Set 7 | kudahuvadhoo
# Processing Record 10 of Set 7 | aklavik
# Processing Record 11 of Set 7 | kamenka
# Processing Record 12 of Set 7 | malmo
# Processing Record 13 of Set 7 | araouane
# Processing Record 14 of Set 7 | abu samrah
# Processing Record 15 of Set 7 | san cristobal
# Processing Record 16 of Set 7 | ponta delgada
# Processing Record 17 of Set 7 | devonport
# Processing Record 18 of Set 7 | qui nhon
# Processing Record 19 of Set 7 | anadyr
# Processing Record 20 of Set 7 | eskisehir
# Processing Record 21 of Set 7 | viedma
# Processing Record 22 of Set 7 | ilulissat
# Processing Record 23 of Set 7 | alice springs
# Processing Record 24 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 25 of Set 7 | bambous virieux
# Processing Record 26 of Set 7 | vaitape
# Processing Record 27 of Set 7 | chokurdakh
# Processing Record 28 of Set 7 | pizarro
# Processing Record 29 of Set 7 | bartica
# Processing Record 30 of Set 7 | asfi
# Processing Record 31 of Set 7 | sorland
# Processing Record 32 of Set 7 | suwannaphum
# Processing Record 33 of Set 7 | sokoni
# Processing Record 34 of Set 7 | nouadhibou
# Processing Record 35 of Set 7 | namibe
# Processing Record 36 of Set 7 | kiama
# Processing Record 37 of Set 7 | turukhansk
# Processing Record 38 of Set 7 | inhambane
# Processing Record 39 of Set 7 | smirice
# Processing Record 40 of Set 7 | khasan
# Processing Record 41 of Set 7 | annau
# Processing Record 42 of Set 7 | saint-pierre
# Processing Record 43 of Set 7 | pangnirtung
# Processing Record 44 of Set 7 | gorontalo
# Processing Record 45 of Set 7 | mabaruma
# Processing Record 46 of Set 7 | singkang
# Processing Record 47 of Set 7 | lufilufi
# Processing Record 48 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 7 | bubaque
# Processing Record 50 of Set 7 | vallenar
# Processing Record 1 of Set 8 | sebinkarahisar
# Processing Record 2 of Set 8 | seymchan
# Processing Record 3 of Set 8 | buarcos
# Processing Record 4 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 8 | barinas
# Processing Record 7 of Set 8 | grand baie
# Processing Record 8 of Set 8 | pervomayskoye
# Processing Record 9 of Set 8 | kosonsoy
# Processing Record 10 of Set 8 | dunedin
# Processing Record 11 of Set 8 | betong
# Processing Record 12 of Set 8 | raudeberg
# Processing Record 13 of Set 8 | loikaw
# Processing Record 14 of Set 8 | kangaatsiaq
# Processing Record 15 of Set 8 | canon city
# Processing Record 16 of Set 8 | srednekolymsk
# Processing Record 17 of Set 8 | brazzaville
# Processing Record 18 of Set 8 | lompoc
# Processing Record 19 of Set 8 | port hawkesbury
# Processing Record 20 of Set 8 | touros
# Processing Record 21 of Set 8 | ye
# City not found. Skipping...
# Processing Record 22 of Set 8 | truth or consequences
# Processing Record 23 of Set 8 | arman
# Processing Record 24 of Set 8 | rondonopolis
# Processing Record 25 of Set 8 | kieta
# Processing Record 26 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 8 | raton
# Processing Record 28 of Set 8 | pachmarhi
# Processing Record 29 of Set 8 | sompeta
# Processing Record 30 of Set 8 | leningradskiy
# Processing Record 31 of Set 8 | kaitangata
# Processing Record 32 of Set 8 | bekesszentandras
# Processing Record 33 of Set 8 | santa cruz de tenerife
# Processing Record 34 of Set 8 | yerbogachen
# Processing Record 35 of Set 8 | scarborough
# Processing Record 36 of Set 8 | gazimurskiy zavod
# Processing Record 37 of Set 8 | udachnyy
# Processing Record 38 of Set 8 | hofn
# Processing Record 39 of Set 8 | hovd
# Processing Record 40 of Set 8 | sterling
# Processing Record 41 of Set 8 | vestmannaeyjar
# Processing Record 42 of Set 8 | peleduy
# Processing Record 43 of Set 8 | roald
# Processing Record 44 of Set 8 | lushunkou
# City not found. Skipping...
# Processing Record 45 of Set 8 | hastings
# Processing Record 46 of Set 8 | liuzhou
# Processing Record 47 of Set 8 | olinda
# Processing Record 48 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 49 of Set 8 | kununurra
# Processing Record 50 of Set 8 | formosa
# Processing Record 1 of Set 9 | talara
# Processing Record 2 of Set 9 | powell river
# Processing Record 3 of Set 9 | najran
# Processing Record 4 of Set 9 | shelburne
# Processing Record 5 of Set 9 | port lincoln
# Processing Record 6 of Set 9 | sitka
# Processing Record 7 of Set 9 | kabinda
# Processing Record 8 of Set 9 | kurchum
# Processing Record 9 of Set 9 | balabac
# Processing Record 10 of Set 9 | rio gallegos
# Processing Record 11 of Set 9 | natal
# Processing Record 12 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 9 | asau
# Processing Record 14 of Set 9 | majene
# Processing Record 15 of Set 9 | betioky
# Processing Record 16 of Set 9 | roma
# Processing Record 17 of Set 9 | los llanos de aridane
# Processing Record 18 of Set 9 | kinkala
# Processing Record 19 of Set 9 | upata
# Processing Record 20 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 9 | yumen
# Processing Record 22 of Set 9 | merauke
# Processing Record 23 of Set 9 | tevaitoa
# Processing Record 24 of Set 9 | llanes
# Processing Record 25 of Set 9 | jutai
# Processing Record 26 of Set 9 | sarishabari
# Processing Record 27 of Set 9 | kholtoson
# Processing Record 28 of Set 9 | tukrah
# Processing Record 29 of Set 9 | peniche
# Processing Record 30 of Set 9 | diapaga
# Processing Record 31 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 9 | barraute
# Processing Record 33 of Set 9 | ossora
# Processing Record 34 of Set 9 | vitim
# Processing Record 35 of Set 9 | bac lieu
# Processing Record 36 of Set 9 | bocaranga
# City not found. Skipping...
# Processing Record 37 of Set 9 | vardo
# Processing Record 38 of Set 9 | codrington
# Processing Record 39 of Set 9 | baghramyan
# Processing Record 40 of Set 9 | arraial do cabo
# Processing Record 41 of Set 9 | deputatskiy
# Processing Record 42 of Set 9 | pokhara
# Processing Record 43 of Set 9 | clocolan
# Processing Record 44 of Set 9 | tatarsk
# Processing Record 45 of Set 9 | baturaja
# Processing Record 46 of Set 9 | urumqi
# Processing Record 47 of Set 9 | westport
# Processing Record 48 of Set 9 | sovetskiy
# Processing Record 49 of Set 9 | port macquarie
# Processing Record 50 of Set 9 | cabo rojo
# Processing Record 1 of Set 10 | atambua
# Processing Record 2 of Set 10 | elko
# Processing Record 3 of Set 10 | artyom
# Processing Record 4 of Set 10 | guanhaes
# Processing Record 5 of Set 10 | tromso
# Processing Record 6 of Set 10 | marawi
# Processing Record 7 of Set 10 | lakatoro
# Processing Record 8 of Set 10 | gambela
# Processing Record 9 of Set 10 | hamilton
# Processing Record 10 of Set 10 | kutum
# Processing Record 11 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 10 | sao filipe
# Processing Record 13 of Set 10 | buala
# Processing Record 14 of Set 10 | reshetylivka
# Processing Record 15 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 10 | kalmunai
# Processing Record 17 of Set 10 | bud
# Processing Record 18 of Set 10 | khor
# Processing Record 19 of Set 10 | tigil
# Processing Record 20 of Set 10 | alofi
# Processing Record 21 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 22 of Set 10 | cranbrook
# Processing Record 23 of Set 10 | rundu
# Processing Record 24 of Set 10 | san miguelito
# Processing Record 25 of Set 10 | san quintin
# Processing Record 26 of Set 10 | kampene
# Processing Record 27 of Set 10 | pozo colorado
# Processing Record 28 of Set 10 | naranjal
# Processing Record 29 of Set 10 | puerto del rosario
# Processing Record 30 of Set 10 | bilma
# Processing Record 31 of Set 10 | san bartolome de tirajana
# Processing Record 32 of Set 10 | katav-ivanovsk
# Processing Record 33 of Set 10 | vila velha
# Processing Record 34 of Set 10 | mangai
# Processing Record 35 of Set 10 | namatanai
# Processing Record 36 of Set 10 | mwinilunga
# Processing Record 37 of Set 10 | adre
# Processing Record 38 of Set 10 | muros
# Processing Record 39 of Set 10 | luganville
# Processing Record 40 of Set 10 | bowen
# Processing Record 41 of Set 10 | portland
# Processing Record 42 of Set 10 | ust-nera
# Processing Record 43 of Set 10 | dutse
# Processing Record 44 of Set 10 | tombouctou
# Processing Record 45 of Set 10 | ajaccio
# Processing Record 46 of Set 10 | kaeo
# Processing Record 47 of Set 10 | tateyama
# Processing Record 48 of Set 10 | redmond
# Processing Record 49 of Set 10 | falavarjan
# Processing Record 50 of Set 10 | aripuana
# Processing Record 1 of Set 11 | nevelsk
# Processing Record 2 of Set 11 | bima
# Processing Record 3 of Set 11 | beira
# Processing Record 4 of Set 11 | linguere
# Processing Record 5 of Set 11 | ixcatepec
# Processing Record 6 of Set 11 | amapa
# Processing Record 7 of Set 11 | khiri mat
# Processing Record 8 of Set 11 | dobson
# Processing Record 9 of Set 11 | batemans bay
# Processing Record 10 of Set 11 | ipixuna
# Processing Record 11 of Set 11 | veraval
# Processing Record 12 of Set 11 | aquin
# Processing Record 13 of Set 11 | la ronge
# Processing Record 14 of Set 11 | onega
# Processing Record 15 of Set 11 | latung
# Processing Record 16 of Set 11 | belaya gora
# Processing Record 17 of Set 11 | ochamchira
# Processing Record 18 of Set 11 | quatre cocos
# Processing Record 19 of Set 11 | greenfield
# Processing Record 20 of Set 11 | poya
# Processing Record 21 of Set 11 | perry
# Processing Record 22 of Set 11 | staryy nadym
# Processing Record 23 of Set 11 | buin
# Processing Record 24 of Set 11 | bambanglipuro
# Processing Record 25 of Set 11 | ahipara
# Processing Record 26 of Set 11 | west wendover
# Processing Record 27 of Set 11 | locri
# Processing Record 28 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 11 | cocal
# Processing Record 30 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 11 | biak
# Processing Record 32 of Set 11 | nador
# Processing Record 33 of Set 11 | komsomolskiy
# Processing Record 34 of Set 11 | puerto carreno
# Processing Record 35 of Set 11 | fortuna foothills
# Processing Record 36 of Set 11 | santa isabel do rio negro
# Processing Record 37 of Set 11 | inuvik
# Processing Record 38 of Set 11 | chinhoyi
# Processing Record 39 of Set 11 | morehead
# Processing Record 40 of Set 11 | marfino
# Processing Record 41 of Set 11 | arco
# Processing Record 42 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 43 of Set 11 | sherlovaya gora
# Processing Record 44 of Set 11 | cape canaveral
# Processing Record 45 of Set 11 | kafue
# Processing Record 46 of Set 11 | goderich
# Processing Record 47 of Set 11 | aberystwyth
# Processing Record 48 of Set 11 | port blair
# Processing Record 49 of Set 11 | aksarka
# Processing Record 50 of Set 11 | sao miguel do araguaia
# Processing Record 1 of Set 12 | ulladulla
# Processing Record 2 of Set 12 | faya
# Processing Record 3 of Set 12 | jacareacanga
# Processing Record 4 of Set 12 | tandil
# Processing Record 5 of Set 12 | faranah
# Processing Record 6 of Set 12 | floro
# Processing Record 7 of Set 12 | solnechnyy
# Processing Record 8 of Set 12 | abha
# Processing Record 9 of Set 12 | ayan
# Processing Record 10 of Set 12 | kashi
# Processing Record 11 of Set 12 | vysotsk
# Processing Record 12 of Set 12 | kars
# Processing Record 13 of Set 12 | aras
# Processing Record 14 of Set 12 | bonthe
# Processing Record 15 of Set 12 | rawson
# Processing Record 16 of Set 12 | itarema
# Processing Record 17 of Set 12 | safford
# Processing Record 18 of Set 12 | codajas
# Processing Record 19 of Set 12 | wanning
# Processing Record 20 of Set 12 | sattahip
# Processing Record 21 of Set 12 | salinopolis
# Processing Record 22 of Set 12 | ayame
# Processing Record 23 of Set 12 | yar-sale
# Processing Record 24 of Set 12 | paamiut
# Processing Record 25 of Set 12 | kelvington
# Processing Record 26 of Set 12 | pedasi
# Processing Record 27 of Set 12 | jos
# Processing Record 28 of Set 12 | hualmay
# Processing Record 29 of Set 12 | maniitsoq
# Processing Record 30 of Set 12 | grand island
# Processing Record 31 of Set 12 | alampur
# Processing Record 32 of Set 12 | puerto escondido
# Processing Record 33 of Set 12 | idah
# Processing Record 34 of Set 12 | mahibadhoo
# Processing Record 35 of Set 12 | misratah
# Processing Record 36 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 37 of Set 12 | laguna
# Processing Record 38 of Set 12 | margate
# Processing Record 39 of Set 12 | vanimo
# Processing Record 40 of Set 12 | ostrovnoy
# Processing Record 41 of Set 12 | honiara
# Processing Record 42 of Set 12 | umm lajj
# Processing Record 43 of Set 12 | bazarnyye mataki
# Processing Record 44 of Set 12 | prince george
# Processing Record 45 of Set 12 | sabang
# Processing Record 46 of Set 12 | puerto suarez
# Processing Record 47 of Set 12 | plerin
# Processing Record 48 of Set 12 | aurillac
# Processing Record 49 of Set 12 | novikovo
# Processing Record 50 of Set 12 | alyangula
# Processing Record 1 of Set 13 | marana
# Processing Record 2 of Set 13 | tshikapa
# Processing Record 3 of Set 13 | taksimo
# Processing Record 4 of Set 13 | kimbe
# Processing Record 5 of Set 13 | lukovetskiy
# Processing Record 6 of Set 13 | zhezkazgan
# Processing Record 7 of Set 13 | ler
# Processing Record 8 of Set 13 | mayumba
# Processing Record 9 of Set 13 | krasnyy chikoy
# Processing Record 10 of Set 13 | brokopondo
# Processing Record 11 of Set 13 | filadelfia
# Processing Record 12 of Set 13 | carnarvon
# Processing Record 13 of Set 13 | coleraine
# Processing Record 14 of Set 13 | abu kamal
# Processing Record 15 of Set 13 | menomonie
# Processing Record 16 of Set 13 | oxford
# Processing Record 17 of Set 13 | ginir
# Processing Record 18 of Set 13 | pocone
# Processing Record 19 of Set 13 | korla
# Processing Record 20 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 13 | yuxia
# Processing Record 22 of Set 13 | karratha
# Processing Record 23 of Set 13 | peace river
# Processing Record 24 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 13 | sisimiut
# Processing Record 26 of Set 13 | hengshui
# Processing Record 27 of Set 13 | agogo
# Processing Record 28 of Set 13 | halifax
# Processing Record 29 of Set 13 | prince rupert
# Processing Record 30 of Set 13 | gonzales
# Processing Record 31 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 32 of Set 13 | kapurthala
# Processing Record 33 of Set 13 | pilao arcado
# City not found. Skipping...
# Processing Record 34 of Set 13 | slave lake
# Processing Record 35 of Set 13 | buchanan
# Processing Record 36 of Set 13 | vostok
# Processing Record 37 of Set 13 | zhuhai
# Processing Record 38 of Set 13 | caucaia
# Processing Record 39 of Set 13 | hami
# Processing Record 40 of Set 13 | warmbad
# Processing Record 41 of Set 13 | maningrida
# Processing Record 42 of Set 13 | chapais
# Processing Record 43 of Set 13 | nara
# Processing Record 44 of Set 13 | adrar
# Processing Record 45 of Set 13 | kalianget
# Processing Record 46 of Set 13 | uren
# Processing Record 47 of Set 13 | amga
# Processing Record 48 of Set 13 | madanapalle
# Processing Record 49 of Set 13 | saint-marc-des-carrieres
# Processing Record 50 of Set 13 | port hardy
# Processing Record 1 of Set 14 | russell
# Processing Record 2 of Set 14 | dhidhdhoo
# Processing Record 3 of Set 14 | hatillo
# Processing Record 4 of Set 14 | huazolotitlan
# City not found. Skipping...
# Processing Record 5 of Set 14 | iaciara
# Processing Record 6 of Set 14 | mezen
# Processing Record 7 of Set 14 | belmonte
# Processing Record 8 of Set 14 | lata
# Processing Record 9 of Set 14 | muyezerskiy
# Processing Record 10 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 11 of Set 14 | acari
# Processing Record 12 of Set 14 | makung
# City not found. Skipping...
# Processing Record 13 of Set 14 | bandipur
# Processing Record 14 of Set 14 | omboue
# Processing Record 15 of Set 14 | san julian
# Processing Record 16 of Set 14 | soyo
# Processing Record 17 of Set 14 | andarab
# City not found. Skipping...
# Processing Record 18 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 14 | waddan
# Processing Record 20 of Set 14 | pontalina
# Processing Record 21 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 14 | rio cuarto
# Processing Record 23 of Set 14 | nome
# Processing Record 24 of Set 14 | wanaka
# Processing Record 25 of Set 14 | makakilo city
# Processing Record 26 of Set 14 | mogadishu
# Processing Record 27 of Set 14 | mangrol
# Processing Record 28 of Set 14 | seoul
# Processing Record 29 of Set 14 | orlik
# Processing Record 30 of Set 14 | varzea da palma
# Processing Record 31 of Set 14 | haines junction
# Processing Record 32 of Set 14 | indramayu
# Processing Record 33 of Set 14 | asyut
# Processing Record 34 of Set 14 | tamiahua
# Processing Record 35 of Set 14 | jalu
# Processing Record 36 of Set 14 | pecos
# Processing Record 37 of Set 14 | couva
# Processing Record 38 of Set 14 | tra vinh
# Processing Record 39 of Set 14 | chimore
# Processing Record 40 of Set 14 | kirakira
# Processing Record 41 of Set 14 | paso de patria
# Processing Record 42 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 14 | alberton
# Processing Record 44 of Set 14 | avera
# Processing Record 45 of Set 14 | huambo
# Processing Record 46 of Set 14 | poddorye
# Processing Record 47 of Set 14 | nirgua
# Processing Record 48 of Set 14 | mende
# Processing Record 49 of Set 14 | niesky
# Processing Record 50 of Set 14 | xingyi
# Processing Record 1 of Set 15 | novaky
# Processing Record 2 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 3 of Set 15 | warwick
# Processing Record 4 of Set 15 | mbengwi
# Processing Record 5 of Set 15 | cumberland
# Processing Record 6 of Set 15 | tarakan
# Processing Record 7 of Set 15 | husavik
# Processing Record 8 of Set 15 | aykhal
# Processing Record 9 of Set 15 | mehamn
# Processing Record 10 of Set 15 | manchester
# Processing Record 11 of Set 15 | wilmington
# Processing Record 12 of Set 15 | hangzhou
# Processing Record 13 of Set 15 | magistralnyy
# Processing Record 14 of Set 15 | agirish
# Processing Record 15 of Set 15 | marsa matruh
# Processing Record 16 of Set 15 | kesennuma
# City not found. Skipping...
# Processing Record 17 of Set 15 | mottola
# Processing Record 18 of Set 15 | jiwani
# Processing Record 19 of Set 15 | itacare
# Processing Record 20 of Set 15 | borogontsy
# Processing Record 21 of Set 15 | port-gentil
# Processing Record 22 of Set 15 | aken
# Processing Record 23 of Set 15 | zarubino
# Processing Record 24 of Set 15 | kropotkin
# Processing Record 25 of Set 15 | sorong
# Processing Record 26 of Set 15 | christchurch
# Processing Record 27 of Set 15 | rincon
# Processing Record 28 of Set 15 | tiznit
# Processing Record 29 of Set 15 | muravlenko
# Processing Record 30 of Set 15 | killam
# Processing Record 31 of Set 15 | marquette
# Processing Record 32 of Set 15 | poso
# Processing Record 33 of Set 15 | bull savanna
# Processing Record 34 of Set 15 | jumla
# Processing Record 35 of Set 15 | ambulu
# Processing Record 36 of Set 15 | emerald
# Processing Record 37 of Set 15 | dzaoudzi
# Processing Record 38 of Set 15 | cabedelo
# Processing Record 39 of Set 15 | fukue
# Processing Record 40 of Set 15 | elat
# Processing Record 41 of Set 15 | shalinskoye
# Processing Record 42 of Set 15 | walvis bay
# Processing Record 43 of Set 15 | faanui
# Processing Record 44 of Set 15 | atherton
# Processing Record 45 of Set 15 | marzuq
# Processing Record 46 of Set 15 | sprancenata
# Processing Record 47 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 48 of Set 15 | chardara
# Processing Record 49 of Set 15 | laborie
# Processing Record 50 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 16 | talcahuano
# Processing Record 2 of Set 16 | garowe
# Processing Record 3 of Set 16 | sohag
# Processing Record 4 of Set 16 | somerset east
# Processing Record 5 of Set 16 | churapcha
# Processing Record 6 of Set 16 | tiquicheo
# Processing Record 7 of Set 16 | chancay
# Processing Record 8 of Set 16 | sampit
# Processing Record 9 of Set 16 | tocopilla
# Processing Record 10 of Set 16 | boardman
# Processing Record 11 of Set 16 | terrace
# Processing Record 12 of Set 16 | pouebo
# Processing Record 13 of Set 16 | grand gaube
# Processing Record 14 of Set 16 | wuzhou
# Processing Record 15 of Set 16 | sierra vista
# Processing Record 16 of Set 16 | presidente medici
# Processing Record 17 of Set 16 | hit
# Processing Record 18 of Set 16 | hunza
# City not found. Skipping...
# Processing Record 19 of Set 16 | birin
# Processing Record 20 of Set 16 | gander
# Processing Record 21 of Set 16 | oyon
# Processing Record 22 of Set 16 | voznesenskoye
# Processing Record 23 of Set 16 | turtkul
# City not found. Skipping...
# Processing Record 24 of Set 16 | sagone
# Processing Record 25 of Set 16 | takoradi
# Processing Record 26 of Set 16 | masterton
# Processing Record 27 of Set 16 | karpathos
# Processing Record 28 of Set 16 | kang
# Processing Record 29 of Set 16 | qaqortoq
# Processing Record 30 of Set 16 | kumluca
# Processing Record 31 of Set 16 | kundgol
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Barrow      US  71.2906 -156.7887     24.82        80           1
# 1       Ushuaia      AR -54.8000  -68.3000     46.06        76           0
# 2     Busselton      AU -33.6500  115.3333     56.08        62          94
# 3  Puerto Ayora      EC  -0.7393  -90.3518     69.60        90          44
# 4       Mataura      NZ -46.1927  168.8643     61.63        49         100
#
#    Wind Speed Weather Description                 Date
# 0       14.97           clear sky  2021-11-01 01:27:36
# 1        9.22           clear sky  2021-11-01 01:23:47
# 2       18.41     overcast clouds  2021-11-01 01:25:32
# 3        7.31    scattered clouds  2021-11-01 01:27:36
# 4       10.96     overcast clouds  2021-11-01 01:27:36

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_vacation.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
